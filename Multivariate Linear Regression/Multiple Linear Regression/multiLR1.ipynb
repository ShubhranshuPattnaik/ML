# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/MLGoogleColabs/advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
import numpy as np
from sklearn import linear_model

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['TV','Radio','Newspaper']],df.Sales)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([0.05444578, 0.10700123, 0.00033566])

# %%
reg.intercept_
# Out:
# 4.625124078808653

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df.TV,df.Radio,df.Newspaper,df.Sales)
plt.plot(df.TV,df.Radio,df.Newspaper,df.Sales)

# %%
reg.predict([[230.1,37.8,69.2]])
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([21.22097209])

# %%
reg.score(df[['TV','Radio','Newspaper']],df.Sales)
# Out:
# 0.9025912899684558
